# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
titanic_train = pd.read_csv("titanic_train.csv")   
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(titanic_train)
# Out:
# pandas.core.frame.DataFrame

# %%
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
type(titanic_train.dtypes)
# Out:
# pandas.core.series.Series

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
dy=titanic_train.dtypes

# %%
dy['PassengerId']
# Out:
# dtype('int64')

# %%
dy
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
l=[0,1,2,3,4,5,'sudh','kumar','iNeuron']

# %%
l[4]
# Out:
# 4

# %%
l[6]
# Out:
# 'sudh'

# %%
dy['PassengerId']
# Out:
# dtype('int64')

# %%
dy[0]
# Out:
# dtype('int64')

# %%
dy[['PassengerId','Name']]
# Out:
# PassengerId     int64
# Name           object
# dtype: object

# %%
dy[[0,3]]
# Out:
# PassengerId     int64
# Name           object
# dtype: object

# %%
dy[0:4]
# Out:
# PassengerId     int64
# Survived        int64
# Pclass          int64
# Name           object
# dtype: object

# %%
dy[0:100:2]
# Out:
# PassengerId     int64
# Pclass          int64
# Sex            object
# SibSp           int64
# Ticket         object
# Cabin          object
# dtype: object

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_train['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
type(titanic_train['Age'])
# Out:
# pandas.core.series.Series

# %%
titanic_train['Age'][10:100]
# Out:
# 10     4.0
# 11    58.0
# 12    20.0
# 13    39.0
# 14    14.0
#       ...
# 95     NaN
# 96    71.0
# 97    23.0
# 98    34.0
# 99    34.0
# Name: Age, Length: 90, dtype: float64

# %%
titanic_train['Age'][::-1]
# Out:
# 890    32.0
# 889    26.0
# 888     NaN
# 887    19.0
# 886    27.0
#        ...
# 4      35.0
# 3      35.0
# 2      26.0
# 1      38.0
# 0      22.0
# Name: Age, Length: 891, dtype: float64

# %%
titanic_train['Age'][-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16300\571722093.py in <module>
# ----> 1 titanic_train['Age'][-1]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     956
#     957         elif key_is_scalar:
# --> 958             return self._get_value(key)
#     959
#     960         if is_hashable(key):
#
# ...

# %%
titanic_train['Age'][::2] #Every second data.

# %%
list(titanic_train['Age'][::2])
# Out:
# [22.0,
#  26.0,
#  35.0,
#  54.0,
#  27.0,
#  4.0,
#  20.0,
#  14.0,
#  2.0,
#  31.0,
#  35.0,
#  15.0,
#  8.0,
#  nan,
#  nan,
#  40.0,
#  nan,
#  28.0,
#  nan,
#  18.0,
#  40.0,
#  nan,
#  19.0,
#  nan,
#  nan,
#  7.0,
#  49.0,
#  65.0,
#  21.0,
#  5.0,
#  22.0,
#  45.0,
#  nan,
#  29.0,
#  17.0,
#  32.0,
#  21.0,
#  32.0,
#  nan,
#  0.83,
#  22.0,
#  nan,
#  17.0,
#  16.0,
#  23.0,
#  29.0,
#  46.0,
#  59.0,
#  71.0,
#  34.0,
#  28.0,
#  21.0,
#  37.0,
#  21.0,
#  38.0,
#  47.0,
#  22.0,
#  17.0,
#  70.5,
#  24.0,
#  21.0,
#  32.5,
#  54.0,
#  nan,
#  nan,
#  33.0,
#  47.0,
#  25.0,
#  19.0,
#  16.0,
#  nan,
#  24.0,
#  18.0,
#  27.0,
#  36.5,
#  51.0,
#  55.5,
#  nan,
#  16.0,
#  nan,
#  44.0,
#  26.0,
#  1.0,
#  nan,
#  nan,
#  61.0,
#  1.0,
#  56.0,
#  nan,
#  30.0,
#  nan,
#  9.0,
#  4.0,
#  nan,
#  40.0,
#  32.0,
#  19.0,
#  44.0,
#  nan,
#  nan,
#  28.0,
#  34.0,
#  18.0,
#  32.0,
#  16.0,
#  24.0,
#  22.0,
#  nan,
#  27.0,
#  32.0,
#  16.0,
#  51.0,
#  38.0,
#  19.0,
# ...

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_train.dtypes[titanic_train.dtypes=='object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
titanic_train.dtypes[titanic_train.dtypes=='object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
titanic_train[titanic_train.dtypes[titanic_train.dtypes=='object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
titanic_train_cat=titanic_train[titanic_train.dtypes[titanic_train.dtypes=='object'].index]

# %%
titanic_train_cat.describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_train["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
type(titanic_train["Name"])
# Out:
# pandas.core.series.Series

# %%
titanic_train[["Name"]]
# Out:
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 886                              Montvila, Rev. Juozas
# 887                       Graham, Miss. Margaret Edith
# 888           Johnston, Miss. Catherine Helen "Carrie"
# 889                              Behr, Mr. Karl Howell
# 890                                Dooley, Mr. Patrick
#
# [891 rows x 1 columns]

# %%
type(titanic_train[["Name"]])
# Out:
# pandas.core.frame.DataFrame

# %%
titanic_train["Age"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
np.where(titanic_train["Age"].isnull()==True) #Here where age=null we find indexs.
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
# ...

# %%
titanic_train[titanic_train["Age"].isnull()==True] #Here where age=null we find all the attribute data.
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
titanic_train_age_null=np.where(titanic_train["Age"].isnull()==True)
titanic_train_age_null
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
# ...

# %%
titanic_train[['Name','Pclass']]
# Out:
#                                                   Name  Pclass
# 0                              Braund, Mr. Owen Harris       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2                               Heikkinen, Miss. Laina       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4                             Allen, Mr. William Henry       3
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas       2
# 887                       Graham, Miss. Margaret Edith       1
# 888           Johnston, Miss. Catherine Helen "Carrie"       3
# 889                              Behr, Mr. Karl Howell       1
# 890                                Dooley, Mr. Patrick       3
#
# [891 rows x 2 columns]

# %%
titanic_train.iloc[titanic_train_age_null]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
titanic_train.iloc[5]
# Out:
# PassengerId                   6
# Survived                      0
# Pclass                        3
# Name           Moran, Mr. James
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                   330877
# Fare                     8.4583
# Cabin                       NaN
# Embarked                      Q
# Name: 5, dtype: object

# %%
type(titanic_train.iloc[5])
# Out:
# pandas.core.series.Series

# %%
titanic_train.iloc[[1,2,3,6,7]]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 6            7         0       1
# 7            8         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S

# %%
titanic_train.iloc[np.where(titanic_train['Fare']==max(titanic_train['Fare']))]['Name'] #Persion name who get heightst fare.
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
titanic_train.iloc[np.where(titanic_train['Fare']==max(titanic_train['Fare']))]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
#2nd method
titanic_train[titanic_train['Fare']==max(titanic_train['Fare'])]['Name'] #Persion name who get heightst fare.
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
titanic_train[titanic_train['Age']==max(titanic_train['Age'])]['Name'] #Persion name who has heightest old.
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
titanic_train[['Age','Cabin']][titanic_train['Cabin'].isnull()==True]
# Out:
#       Age Cabin
# 0    22.0   NaN
# 2    26.0   NaN
# 4    35.0   NaN
# 5     NaN   NaN
# 7     2.0   NaN
# ..    ...   ...
# 884  25.0   NaN
# 885  39.0   NaN
# 886  27.0   NaN
# 888   NaN   NaN
# 890  32.0   NaN
#
# [687 rows x 2 columns]

# %%
titanic_train.iloc[np.where(titanic_train['Cabin'].isnull()==True)] #Find all the data frame where Cabin is NaN.
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
titanic_train.iloc[np.where(titanic_train['Cabin'].isnull()==True)][['Age','Cabin']]
# Out:
#       Age Cabin
# 0    22.0   NaN
# 2    26.0   NaN
# 4    35.0   NaN
# 5     NaN   NaN
# 7     2.0   NaN
# ..    ...   ...
# 884  25.0   NaN
# 885  39.0   NaN
# 886  27.0   NaN
# 888   NaN   NaN
# 890  32.0   NaN
#
# [687 rows x 2 columns]

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#How many passenger has servived who has male?
titanic_train[titanic_train['Survived']==1][titanic_train['Sex']=='male']
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16300\3294844491.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   titanic_train[titanic_train['Survived']==1][titanic_train['Sex']=='male']
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 17            18         1       2     Williams, Mr. Charles Eugene  male
# 21            22         1       2            Beesley, Mr. Lawrence  male
# 23            24         1       1     Sloper, Mr. William Thompson  male
# 36            37         1       3                 Mamee, Mr. Hanna  male
# 55            56         1       1                Woolner, Mr. Hugh  male
# ..           ...       ...     ...                              ...   ...
# 838          839         1       3                  Chip, Mr. Chang  male
# 839          840         1       1             Marechal, Mr. Pierre  male
# 857          858         1       1           Daly, Mr. Peter Denis   male
# ...

# %%
titanic_train[titanic_train['Survived']==1][titanic_train['Sex']=='male']['Name']
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16300\2006245887.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   titanic_train[titanic_train['Survived']==1][titanic_train['Sex']=='male']['Name']
# 17        Williams, Mr. Charles Eugene
# 21               Beesley, Mr. Lawrence
# 23        Sloper, Mr. William Thompson
# 36                    Mamee, Mr. Hanna
# 55                   Woolner, Mr. Hugh
#                     ...
# 838                    Chip, Mr. Chang
# 839               Marechal, Mr. Pierre
# 857             Daly, Mr. Peter Denis
# 869    Johnson, Master. Harold Theodor
# 889              Behr, Mr. Karl Howell
# Name: Name, Length: 109, dtype: object

# %%
#2nd Metod
titanic_train[(titanic_train['Sex']=='male') & titanic_train['Survived']==1]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 17            18         1       2     Williams, Mr. Charles Eugene  male
# 21            22         1       2            Beesley, Mr. Lawrence  male
# 23            24         1       1     Sloper, Mr. William Thompson  male
# 36            37         1       3                 Mamee, Mr. Hanna  male
# 55            56         1       1                Woolner, Mr. Hugh  male
# ..           ...       ...     ...                              ...   ...
# 838          839         1       3                  Chip, Mr. Chang  male
# 839          840         1       1             Marechal, Mr. Pierre  male
# 857          858         1       1           Daly, Mr. Peter Denis   male
# 869          870         1       3  Johnson, Master. Harold Theodor  male
# 889          890         1       1            Behr, Mr. Karl Howell  male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...

# %%
titanic_train[(titanic_train['Sex']=='male') & titanic_train['Survived']==1]['Name']
# Out:
# 17        Williams, Mr. Charles Eugene
# 21               Beesley, Mr. Lawrence
# 23        Sloper, Mr. William Thompson
# 36                    Mamee, Mr. Hanna
# 55                   Woolner, Mr. Hugh
#                     ...
# 838                    Chip, Mr. Chang
# 839               Marechal, Mr. Pierre
# 857             Daly, Mr. Peter Denis
# 869    Johnson, Master. Harold Theodor
# 889              Behr, Mr. Karl Howell
# Name: Name, Length: 109, dtype: object

# %%
titanic_train['new_col']='sudh'

# %%
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
l=[1,2,3,4,5]

# %%
pd.Series(l)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.DataFrame(l)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
d={'key':'sudh','title':'kumar','mail_id':'sudh@gamil.com'}

# %%
pd.Series(d)
# Out:
# key                  sudh
# title               kumar
# mail_id    sudh@gamil.com
# dtype: object

# %%
pd.DataFrame(d,index=[2])
# Out:
#     key  title         mail_id
# 2  sudh  kumar  sudh@gamil.com

# %%
pd.DataFrame(d,index=[2,6])
# Out:
#     key  title         mail_id
# 2  sudh  kumar  sudh@gamil.com
# 6  sudh  kumar  sudh@gamil.com

# %%
arr=np.random.randn(3,4)
arr
# Out:
# array([[-0.01011758,  0.55209396,  1.06411942,  0.91682578],
#        [ 0.88721276,  0.83527089,  0.07678343, -0.73480598],
#        [-0.25551821,  0.7230252 , -1.58089633, -0.022156  ]])

# %%
pd.DataFrame(arr)
# Out:
#           0         1         2         3
# 0 -0.010118  0.552094  1.064119  0.916826
# 1  0.887213  0.835271  0.076783 -0.734806
# 2 -0.255518  0.723025 -1.580896 -0.022156

# %%
pd.Series(arr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16300\2396573727.py in <module>
# ----> 1 pd.Series(arr)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     449                     data = data.copy()
#     450             else:
# --> 451                 data = sanitize_array(data, index, dtype, copy)
#     452
#     453                 manager = get_option("mode.data_manager")
#
# ~\anaconda3\lib\site-packages\pandas\core\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure, allow_2d)
#     599                 subarr = maybe_infer_to_datetimelike(subarr)
#     600
# --> 601     subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     602
#     603     if isinstance(subarr, np.ndarray):
#
# ...

# %%
pd.Series(np.array([4,5,6,7,8]))
# Out:
# 0    4
# 1    5
# 2    6
# 3    7
# 4    8
# dtype: int32

# %%
ser=pd.Series(np.array([4,5,6,7,8]),index=['a','b','sudh','kumar','c'])
ser
# Out:
# a        4
# b        5
# sudh     6
# kumar    7
# c        8
# dtype: int32

# %%
ser['sudh']
# Out:
# 6

# %%
ser.loc['sudh']
# Out:
# 6

# %%
ser.ilco['sudh']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16300\633502316.py in <module>
# ----> 1 ser.ilco['sudh']
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'ilco'

# %%
ser.iloc[2]
# Out:
# 6

# %%
ser1=pd.Series(np.array([4,5,6,7,8]),index=[45,51,62,75,83])
ser1
# Out:
# 45    4
# 51    5
# 62    6
# 75    7
# 83    8
# dtype: int32

# %%
ser1.iloc[51] #Not int inbuild int take named indexes.
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16300\1158159280.py in <module>
# ----> 1 ser1.iloc[51]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967             return self._getitem_axis(maybe_callable, axis=axis)
#     968
#     969     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1521
#    1522             # validate the location
# -> 1523             self._validate_integer(key, axis)
#    1524
#    1525             return self.obj._ixs(key, axis=axis)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1453         len_axis = len(self.obj._get_axis(axis))
# ...

# %%
ser1.loc[51]
# Out:
# 5

# %%
np.random.randint(3,6,(4,5))
# Out:
# array([[3, 4, 3, 3, 4],
#        [4, 5, 5, 4, 5],
#        [4, 4, 3, 3, 3],
#        [5, 5, 4, 4, 4]])

# %%
df=pd.DataFrame(np.random.randint(3,6,(4,5)),index=['a','b','c','d'],columns=['x','y','z','u','v'])
df
# Out:
#    x  y  z  u  v
# a  4  5  4  5  4
# b  5  3  3  4  4
# c  5  3  4  4  3
# d  5  5  3  5  3

# %%
df.loc[['c','d'],['z','u']]
# Out:
#    z  u
# c  5  4
# d  5  3

# %%
df.iloc[[2,3],[2,3]]
# Out:
#    z  u
# c  5  4
# d  5  3

# %%
df.iloc[2:4,2:4]
# Out:
#    z  u
# c  5  4
# d  5  3

# %%
df
# Out:
#    x  y  z  u  v
# a  3  4  3  3  5
# b  3  5  3  3  3
# c  4  5  5  4  4
# d  4  5  5  3  5

# %%
df['new']=df['x']+df.y

# %%
df
# Out:
#    x  y  z  u  v  new
# a  3  4  3  3  5    7
# b  3  5  3  3  3    8
# c  4  5  5  4  4    9
# d  4  5  5  3  5    9

# %%
df.drop('x',axis=1)
# Out:
#    y  z  u  v
# a  5  4  5  4
# b  3  3  4  4
# c  3  4  4  3
# d  5  3  5  3

# %%
df
# Out:
#    x  y  z  u  v
# a  4  5  4  5  4
# b  5  3  3  4  4
# c  5  3  4  4  3
# d  5  5  3  5  3

# %%
df.drop('x',axis=1,inplace=True)
df
# Out:
#    y  z  u  v
# a  5  4  5  4
# b  3  3  4  4
# c  3  4  4  3
# d  5  3  5  3

# %%
df.drop('d')
# Out:
#    y  z  u  v
# a  5  4  5  4
# b  3  3  4  4
# c  3  4  4  3

# %%
df
# Out:
#    y  z  u  v
# a  5  4  5  4
# b  3  3  4  4
# c  3  4  4  3
# d  5  3  5  3

# %%
np.random.seed(23)
pd.DataFrame(np.random.randn(4,5),index=['a','b','c','d'],columns=['x','y','z','u','v'])
# Out:
#           x         y         z         u         v
# a  0.666988  0.025813 -0.777619  0.948634  0.701672
# b -1.051082 -0.367548 -1.137460 -1.322148  1.772258
# c -0.347459  0.670140  0.322272  0.060343 -1.043450
# d -1.009942  0.441736  1.128877 -1.838068 -0.938769

# %%
#Etract all negative values?

# %%
df=pd.DataFrame(np.random.randn(4,5),index=['a','b','c','d'],columns=['x','y','z','u','v'])

# %%
#Ans.
df.values[df.values<0]
# Out:
# array([-0.20184052, -0.95250953, -0.13626676, -1.22325477, -0.54778801,
#        -0.67941827, -2.50623032, -0.02253889])

# %%
#2nd method
for i in df.columns:
    for j in df.index:
        if df[i][j] < 0:
            print(i,j,"=",df[i][j])
# Out:
# x a = -0.20184052243138237
# x b = -0.9525095310029906
# x d = -0.6794182716515045
# y b = -0.13626675631863647
# y d = -2.506230317020084
# v b = -1.223254774207143
# v c = -0.547788007825014
# v d = -0.022538890053004787

# %%
#3nd method
for i in df.columns:
    for j in df.index:
        if df.loc[j,i] < 0:
            print(i,j,"=",df.loc[j,i])
# Out:
# x a = -0.20184052243138237
# x b = -0.9525095310029906
# x d = -0.6794182716515045
# y b = -0.13626675631863647
# y d = -2.506230317020084
# v b = -1.223254774207143
# v c = -0.547788007825014
# v d = -0.022538890053004787

# %%
df.values
# Out:
# array([[-0.20184052,  1.04537128,  0.53816197,  0.81211867,  0.2411063 ],
#        [-0.95250953, -0.13626676,  1.26724821,  0.17363364, -1.22325477],
#        [ 1.41531998,  0.45771098,  0.72887584,  1.96843473, -0.54778801],
#        [-0.67941827, -2.50623032,  0.14696049,  0.60619549, -0.02253889]])

# %%
df.loc[['a'],['x']]
# Out:
#           x
# a -0.201841

# %%
d={'key1':[1,2,3,4,np.nan],'key2':['sudh','kumar',4,5,6],'key3':[np.nan,np.nan,np.nan,3,8]}
df=pd.DataFrame(d)

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0      4   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna()
# Out:
#    key1 key2  key3
# 3   4.0    5   3.0

# %%
df.dropna(axis=1)
# Out:
#     key2
# 0   sudh
# 1  kumar
# 2      4
# 3      5
# 4      6

# %%
df.dropna(thresh=0)
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0      4   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(axis=1,thresh=0)
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0      4   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=1)
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0      4   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(axis=1,thresh=1)
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0      4   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=2)
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0      4   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(axis=1,thresh=2)
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0      4   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=3)
# Out:
#    key1 key2  key3
# 3   4.0    5   3.0

# %%
df.dropna(axis=1,thresh=3)
# Out:
#    key1   key2
# 0   1.0   sudh
# 1   2.0  kumar
# 2   3.0      4
# 3   4.0      5
# 4   NaN      6

# %%
df.dropna(thresh=4)
# Out:
# Empty DataFrame
# Columns: [key1, key2, key3]
# Index: []

# %%
df.dropna(axis=1,thresh=4)
# Out:
#    key1   key2
# 0   1.0   sudh
# 1   2.0  kumar
# 2   3.0      4
# 3   4.0      5
# 4   NaN      6

# %%
df.dropna(axis=1,thresh=5)
# Out:
#     key2
# 0   sudh
# 1  kumar
# 2      4
# 3      5
# 4      6

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0      4   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.fillna('sudh')
# Out:
#    key1   key2  key3
# 0   1.0   sudh  sudh
# 1   2.0  kumar  sudh
# 2   3.0      4  sudh
# 3   4.0      5   3.0
# 4  sudh      6   8.0

# %%
df.fillna(df['key1'].mean())
# Out:
#    key1   key2  key3
# 0   1.0   sudh   2.5
# 1   2.0  kumar   2.5
# 2   3.0      4   2.5
# 3   4.0      5   3.0
# 4   2.5      6   8.0

# %%
d1 = {'name' :['sudh' , 'visal' , 'umang', 'vishal' ,'umang'],"mail_id" :["sudh@gmail.com", "vishal@gmail.com",'umang@gmail.com','vishal@gmail.com','umang@gmail.com'],
     'salary' :[100,200,500,200,500]}
df=pd.DataFrame(d1)

# %%
df
# Out:
#      name           mail_id  salary
# 0    sudh    sudh@gmail.com     100
# 1   visal  vishal@gmail.com     200
# 2   umang   umang@gmail.com     500
# 3  vishal  vishal@gmail.com     200
# 4   umang   umang@gmail.com     500

# %%
df.groupby('name').mean()
# Out:
#         salary
# name
# sudh     100.0
# umang    500.0
# visal    200.0
# vishal   200.0

# %%
df.groupby('mail_id').mean()
# Out:
#                   salary
# mail_id
# sudh@gmail.com     100.0
# umang@gmail.com    500.0
# vishal@gmail.com   200.0

# %%
df.groupby('mail_id').sum()
# Out:
#                   salary
# mail_id
# sudh@gmail.com       100
# umang@gmail.com     1000
# vishal@gmail.com     400

# %%
df.groupby('mail_id').describe()
# Out:
#                  salary
#                   count   mean  std    min    25%    50%    75%    max
# mail_id
# sudh@gmail.com      1.0  100.0  NaN  100.0  100.0  100.0  100.0  100.0
# umang@gmail.com     2.0  500.0  0.0  500.0  500.0  500.0  500.0  500.0
# vishal@gmail.com    2.0  200.0  0.0  200.0  200.0  200.0  200.0  200.0

# %%
type(df.groupby('mail_id').describe())
# Out:
# pandas.core.frame.DataFrame

# %%
#Find statistic of umang@gmail.com using groupby?
df.groupby('mail_id').describe().loc['umang@gmail.com']
# Out:
# salary  count      2.0
#         mean     500.0
#         std        0.0
#         min      500.0
#         25%      500.0
#         50%      500.0
#         75%      500.0
#         max      500.0
# Name: umang@gmail.com, dtype: float64

# %%
df.groupby('mail_id').describe().iloc[1]
# Out:
# salary  count      2.0
#         mean     500.0
#         std        0.0
#         min      500.0
#         25%      500.0
#         50%      500.0
#         75%      500.0
#         max      500.0
# Name: umang@gmail.com, dtype: float64

# %%
type(df.groupby('mail_id').describe().loc['umang@gmail.com'])
# Out:
# pandas.core.series.Series

# %%
df.groupby('mail_id').describe().loc['umang@gmail.com']
# Out:
# salary  count      2.0
#         mean     500.0
#         std        0.0
#         min      500.0
#         25%      500.0
#         50%      500.0
#         75%      500.0
#         max      500.0
# Name: umang@gmail.com, dtype: float64

# %%
df.groupby('mail_id').describe().loc['umang@gmail.com']['salary']
# Out:
# count      2.0
# mean     500.0
# std        0.0
# min      500.0
# 25%      500.0
# 50%      500.0
# 75%      500.0
# max      500.0
# Name: umang@gmail.com, dtype: float64

# %%
df.groupby('mail_id').describe().loc['umang@gmail.com']['salary']['mean']
# Out:
# 500.0

# %%
df.groupby('mail_id').describe().loc['umang@gmail.com']['salary']['count']
# Out:
# 2.0

# %%
df.groupby('mail_id').describe().T
# Out:
# mail_id       sudh@gmail.com  umang@gmail.com  vishal@gmail.com
# salary count             1.0              2.0               2.0
#        mean            100.0            500.0             200.0
#        std               NaN              0.0               0.0
#        min             100.0            500.0             200.0
#        25%             100.0            500.0             200.0
#        50%             100.0            500.0             200.0
#        75%             100.0            500.0             200.0
#        max             100.0            500.0             200.0

# %%
df.groupby('mail_id').describe()
# Out:
#                  salary
#                   count   mean  std    min    25%    50%    75%    max
# mail_id
# sudh@gmail.com      1.0  100.0  NaN  100.0  100.0  100.0  100.0  100.0
# umang@gmail.com     2.0  500.0  0.0  500.0  500.0  500.0  500.0  500.0
# vishal@gmail.com    2.0  200.0  0.0  200.0  200.0  200.0  200.0  200.0

# %%
arr1=np.random.randn(3,4)
arr2=np.random.randn(3,4)
arr3=np.random.randn(3,4)

# %%
df1=pd.DataFrame(arr1,columns=['A','B','C','D'])
df2=pd.DataFrame(arr2,columns=['A','B','C','D'])
df3=pd.DataFrame(arr3,columns=['A','B','C','D'])

# %%
df1
# Out:
#           A         B         C        D
# 0 -0.133025 -0.017357 -0.101093 -0.56404
# 1 -0.179036  1.011059  0.920996  1.93309
# 2 -0.795363 -1.011535  2.150780  0.42514

# %%
df2
# Out:
#           A         B         C         D
# 0  0.441152 -0.817439  0.437892  0.099723
# 1  0.065406  1.224431 -0.769599  0.192120
# 2 -1.723253  0.461259 -1.085367  1.823378

# %%
df3
# Out:
#           A         B         C         D
# 0 -1.332863  1.637391 -0.822939 -1.598109
# 1  0.226512  0.233898 -0.947222 -1.261576
# 2 -2.389866 -0.333274  0.343517 -2.027861

# %%
pd.concat([df1,df2,df3])
# Out:
#           A         B         C         D
# 0 -0.133025 -0.017357 -0.101093 -0.564040
# 1 -0.179036  1.011059  0.920996  1.933090
# 2 -0.795363 -1.011535  2.150780  0.425140
# 0  0.441152 -0.817439  0.437892  0.099723
# 1  0.065406  1.224431 -0.769599  0.192120
# 2 -1.723253  0.461259 -1.085367  1.823378
# 0 -1.332863  1.637391 -0.822939 -1.598109
# 1  0.226512  0.233898 -0.947222 -1.261576
# 2 -2.389866 -0.333274  0.343517 -2.027861

# %%
pd.concat([df1,df2,df3],axis=1)
# Out:
#           A         B         C        D         A         B         C  \
# 0 -0.133025 -0.017357 -0.101093 -0.56404  0.441152 -0.817439  0.437892
# 1 -0.179036  1.011059  0.920996  1.93309  0.065406  1.224431 -0.769599
# 2 -0.795363 -1.011535  2.150780  0.42514 -1.723253  0.461259 -1.085367
#
#           D         A         B         C         D
# 0  0.099723 -1.332863  1.637391 -0.822939 -1.598109
# 1  0.192120  0.226512  0.233898 -0.947222 -1.261576
# 2  1.823378 -2.389866 -0.333274  0.343517 -2.027861

# %%
df4=pd.concat([df1,df2,df3])

# %%
df4
# Out:
#           A         B         C         D
# 0 -0.133025 -0.017357 -0.101093 -0.564040
# 1 -0.179036  1.011059  0.920996  1.933090
# 2 -0.795363 -1.011535  2.150780  0.425140
# 0  0.441152 -0.817439  0.437892  0.099723
# 1  0.065406  1.224431 -0.769599  0.192120
# 2 -1.723253  0.461259 -1.085367  1.823378
# 0 -1.332863  1.637391 -0.822939 -1.598109
# 1  0.226512  0.233898 -0.947222 -1.261576
# 2 -2.389866 -0.333274  0.343517 -2.027861

# %%
df4.iloc[0]
# Out:
# A   -0.133025
# B   -0.017357
# C   -0.101093
# D   -0.564040
# Name: 0, dtype: float64

# %%
df4.loc[0]
# Out:
#           A         B         C         D
# 0 -0.133025 -0.017357 -0.101093 -0.564040
# 0  0.441152 -0.817439  0.437892  0.099723
# 0 -1.332863  1.637391 -0.822939 -1.598109

# %%
df5=pd.concat([df1,df2,df3],axis=1)
df5
# Out:
#           A         B         C        D         A         B         C  \
# 0 -0.133025 -0.017357 -0.101093 -0.56404  0.441152 -0.817439  0.437892
# 1 -0.179036  1.011059  0.920996  1.93309  0.065406  1.224431 -0.769599
# 2 -0.795363 -1.011535  2.150780  0.42514 -1.723253  0.461259 -1.085367
#
#           D         A         B         C         D
# 0  0.099723 -1.332863  1.637391 -0.822939 -1.598109
# 1  0.192120  0.226512  0.233898 -0.947222 -1.261576
# 2  1.823378 -2.389866 -0.333274  0.343517 -2.027861

# %%
df5['A']
# Out:
#           A         A         A
# 0 -0.133025  0.441152 -1.332863
# 1 -0.179036  0.065406  0.226512
# 2 -0.795363 -1.723253 -2.389866

# %%
df5.iloc[:,4] # I want to 2nd A value? (4 is 4th col in df5)
# Out:
# 0    0.441152
# 1    0.065406
# 2   -1.723253
# Name: A, dtype: float64

# %%
df1=pd.DataFrame(arr1,columns=['A','B','C','D'],index=[0,1,2])
df2=pd.DataFrame(arr2,columns=['A','B','C','D'],index=[3,4,5])
df3=pd.DataFrame(arr3,columns=['A','B','C','D'],index=[6,7,8])

# %%
pd.concat([df1,df2,df3],axis=1)
# Out:
#           A         B         C        D         A         B         C  \
# 0 -0.133025 -0.017357 -0.101093 -0.56404       NaN       NaN       NaN
# 1 -0.179036  1.011059  0.920996  1.93309       NaN       NaN       NaN
# 2 -0.795363 -1.011535  2.150780  0.42514       NaN       NaN       NaN
# 3       NaN       NaN       NaN      NaN  0.441152 -0.817439  0.437892
# 4       NaN       NaN       NaN      NaN  0.065406  1.224431 -0.769599
# 5       NaN       NaN       NaN      NaN -1.723253  0.461259 -1.085367
# 6       NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 7       NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 8       NaN       NaN       NaN      NaN       NaN       NaN       NaN
#
#           D         A         B         C         D
# 0       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN
# ...

# %%
pd.concat([df1,df2,df3],axis=1).fillna(0)
# Out:
#           A         B         C        D         A         B         C  \
# 0 -0.133025 -0.017357 -0.101093 -0.56404  0.000000  0.000000  0.000000
# 1 -0.179036  1.011059  0.920996  1.93309  0.000000  0.000000  0.000000
# 2 -0.795363 -1.011535  2.150780  0.42514  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.00000  0.441152 -0.817439  0.437892
# 4  0.000000  0.000000  0.000000  0.00000  0.065406  1.224431 -0.769599
# 5  0.000000  0.000000  0.000000  0.00000 -1.723253  0.461259 -1.085367
# 6  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 7  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 8  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
#
#           D         A         B         C         D
# 0  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  0.000000  0.000000
# ...

# %%
np.random.seed(23)
arr1 = np.random.randn(3,4)
np.random.seed(23)
arr2 = np.random.randn(3,4)
df11 = pd.DataFrame(arr1,columns=["A","B","C","D"],index = [0,1,2])
df22 = pd.DataFrame(arr2,columns=["A","B","C","D"],index = [3,4,5])

# %%
df11
# Out:
#           A         B         C         D
# 0  0.666988  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460
# 2 -1.322148  1.772258 -0.347459  0.670140

# %%
df22
# Out:
#           A         B         C         D
# 3  0.666988  0.025813 -0.777619  0.948634
# 4  0.701672 -1.051082 -0.367548 -1.137460
# 5 -1.322148  1.772258 -0.347459  0.670140

# %%
pd.merge(df11,df22,on='A')
# Out:
#           A       B_x       C_x       D_x       B_y       C_y       D_y
# 0  0.666988  0.025813 -0.777619  0.948634  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460 -1.051082 -0.367548 -1.137460
# 2 -1.322148  1.772258 -0.347459  0.670140  1.772258 -0.347459  0.670140

# %%
df1 = pd.DataFrame({'key': ['K0', 'K1', 'K0', 'K1'],
                        'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3']})
    
df2 = pd.DataFrame({'key': ['K0', 'K1', 'K1', 'K2'],
                             'C': ['C0', 'C1', 'C2', 'C3'],
                            'D': ['D0', 'D1', 'D2', 'D3']})

# %%
df1
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K0  A2  B2
# 3  K1  A3  B3

# %%
df2
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K1  C2  D2
# 3  K2  C3  D3

# %%
pd.merge(df1,df2,on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K0  A2  B2  C0  D0
# 2  K1  A1  B1  C1  D1
# 3  K1  A1  B1  C2  D2
# 4  K1  A3  B3  C1  D1
# 5  K1  A3  B3  C2  D2

# %%
pd.merge(df1,df2,on='key',how='left')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K1  A1  B1  C2  D2
# 3  K0  A2  B2  C0  D0
# 4  K1  A3  B3  C1  D1
# 5  K1  A3  B3  C2  D2

# %%
pd.merge(df1,df2,on='key',how='right')
# Out:
#   key    A    B   C   D
# 0  K0   A0   B0  C0  D0
# 1  K0   A2   B2  C0  D0
# 2  K1   A1   B1  C1  D1
# 3  K1   A3   B3  C1  D1
# 4  K1   A1   B1  C2  D2
# 5  K1   A3   B3  C2  D2
# 6  K2  NaN  NaN  C3  D3

# %%
pd.merge(df1,df2,on='key',how='outer')
# Out:
#   key    A    B   C   D
# 0  K0   A0   B0  C0  D0
# 1  K0   A2   B2  C0  D0
# 2  K1   A1   B1  C1  D1
# 3  K1   A1   B1  C2  D2
# 4  K1   A3   B3  C1  D1
# 5  K1   A3   B3  C2  D2
# 6  K2  NaN  NaN  C3  D3

# %%
df1 = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                        'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3']})
    
df2 = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                               'key2': ['K0', 'K0', 'K0', 'K0'],
                                  'C': ['C0', 'C1', 'C2', 'C3'],
                                  'D': ['D0', 'D1', 'D2', 'D3']})

# %%
pd.merge(df1,df2,on=['key1','key2'])
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
df1 = pd.DataFrame({
                        'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3']},
                           index=['K0','K1','K2','K4'])
    
df2 = pd.DataFrame({    'C': ['C0', 'C1', 'C2', 'C3'],
                                  'D': ['D0', 'D1', 'D2', 'D3']},
                                index=['K0','K1','K2','K3'])

# %%
df1
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2
# K4  A3  B3

# %%
df2
# Out:
#      C   D
# K0  C0  D0
# K1  C1  D1
# K2  C2  D2
# K3  C3  D3

# %%
df1.join(df2,how='outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1   C1   D1
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3
# K4   A3   B3  NaN  NaN
